# %%
import fecfile
import pandas as pd
import datetime
import re

# %% [markdown]
# Time the notebook

# %%
start = datetime.datetime.now()

# %% [markdown]
# Set some viewing options

# %%
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_columns', 40)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Parse all the raw FEC numbers we wrote to CSV

# %% [markdown]
# ### But first, some convenience functions..

# %% [markdown]
# This function, when given a filing ID, returns only the earmarked contributions from individual donors to candidates:

# %%
def extract_contributions(filing_id):
    
    filename = f"../data/filings/{filing_id}-schedule-a.csv"
    
    sched_a = pd.read_csv(
        filename,
        parse_dates = ["contribution_date"],
        dtype = {
            "entity_type": str,
            "filer_committee_id_number": str,
            "transaction_id": str,
            "contribution_amount": float,
            "contribution_aggregate": float,
            "contributor_organization_name": str,
            "contributor_first_name": str,
            "contributor_last_name": str,
            "contributor_street_1": str,
            "contributor_street_2": str,
            "contributor_city": str,
            "contributor_zip_code": str,
            "contributor_state": str,
            "contributor_employer": str,
            "contributor_occupation": str,
            "contribution_purpose_descrip": str,
            "memo_code": str,
            "memo_text_description": str
        }
    )
        
    # remove time zone
    sched_a["contribution_date"] = sched_a["contribution_date"].dt.tz_localize(None)

    return (
        sched_a
        # Extract only individual contributions
        .loc[lambda df: df["entity_type"] == "IND"]
        # Remove memo lines
        .loc[lambda df: df["memo_code"].isnull()]
        # Remove donations that are not for a specific candidate
        .loc[ lambda df: df["contribution_purpose_descrip"] == "Earmark" ]
        .assign(
            filing_id = str(filing_id),
        )
    )

# %% [markdown]
# Create a unique ID out of first name, last name and 5-digit ZIP code

# %%
def make_donor_ids(df):
    return (
        df
        .assign(
            donor_id = lambda df: (
                df
                .assign(
                    
                    zip5 = lambda df: (
                        df["contributor_zip_code"]
                        .fillna("-----")
                        .str.slice(0, 5)
                    )
                )
                [[
                    "contributor_first_name",
                    "contributor_last_name",
                    "zip5",
                ]]
                .apply(lambda x: (
                    x
                    .fillna("")
                    .astype(str)
                    # Remove periods, commas, extra whitespace
                    .str.replace(r"[\.,\s]+", " ")
                    .str.strip()
                    # Convert everything to upper-case
                    .str.upper()
                ))
                .apply("|".join, axis = 1)
            )
        )
    )

# %% [markdown]
# Add a donor name column

# %%
def extract_committee_id(df):
    return (
        df
        .assign(
            committee_id = lambda df: df["memo_text_description"].str.extract(r"\((C\d{8})\)", expand = False),
            actblue_committee_name = lambda df: (
                df
                ["memo_text_description"]
                .str.extract(r"^Earmarked for (.*)?\(C\d{8}\)", expand = False)
                .str.strip()
            ),
        )
    )

# %% [markdown]
# Load and make ids

# %%
all_actblue = (
    extract_contributions("1344765")
    .pipe( make_donor_ids )
    .pipe( extract_committee_id )
)

all_actblue.head()
# Out:
#     entity_type filer_committee_id_number    transaction_id contribution_date  \
# 256         IND                 C00401224  SA11AI_146307598        2019-01-31
# 257         IND                 C00401224  SA11AI_148902257        2019-02-28
# 260         IND                 C00401224  SA11AI_152480924        2019-03-31
# 261         IND                 C00401224  SA11AI_156075790        2019-04-30
# 264         IND                 C00401224  SA11AI_159499460        2019-05-31
#
#      contribution_amount  contribution_aggregate  \
# 256                  4.0                    24.0
# 257                  4.0                    24.0
# 260                  4.0                    24.0
# 261                  4.0                    24.0
# 264                  4.0                    24.0
#
#     contributor_organization_name contributor_first_name  \
# 256                           NaN                  SUSAN
# 257                           NaN                  SUSAN
# 260                           NaN                  SUSAN
# 261                           NaN                  SUSAN
# 264                           NaN                  SUSAN
#
#          contributor_last_name                contributor_street_1  \
# 256  A - A (MYSELF) SUSAN WEBB  195 LARPENTEUR AVE W MARION ST APA
# 257  A - A (MYSELF) SUSAN WEBB  195 LARPENTEUR AVE W MARION ST APA
# 260  A - A (MYSELF) SUSAN WEBB  195 LARPENTEUR AVE W MARION ST APA
# 261  A - A (MYSELF) SUSAN WEBB  195 LARPENTEUR AVE W MARION ST APA
# 264  A - A (MYSELF) SUSAN WEBB  195 LARPENTEUR AVE W MARION ST APA
#
#     contributor_street_2 contributor_city contributor_zip_code  \
# 256                  NaN        ROSEVILLE                55113
# 257                  NaN        ROSEVILLE                55113
# 260                  NaN        ROSEVILLE                55113
# 261                  NaN        ROSEVILLE                55113
# 264                  NaN        ROSEVILLE                55113
#
#     contributor_state contributor_employer contributor_occupation  \
# 256                MN                APPLE                 RETAIL
# 257                MN                APPLE                 RETAIL
# 260                MN                APPLE                 RETAIL
# 261                MN                APPLE                 RETAIL
# 264                MN                APPLE                 RETAIL
#
#     contribution_purpose_descrip memo_code           memo_text_description  \
# 256                      Earmark       NaN  Earmarked for DCCC (C00000935)
# 257                      Earmark       NaN  Earmarked for DCCC (C00000935)
# 260                      Earmark       NaN  Earmarked for DCCC (C00000935)
# 261                      Earmark       NaN  Earmarked for DCCC (C00000935)
# 264                      Earmark       NaN  Earmarked for DCCC (C00000935)
#
#     filing_id                               donor_id committee_id  \
# 256   1344765  SUSAN|A - A (MYSELF) SUSAN WEBB|55113    C00000935
# 257   1344765  SUSAN|A - A (MYSELF) SUSAN WEBB|55113    C00000935
# 260   1344765  SUSAN|A - A (MYSELF) SUSAN WEBB|55113    C00000935
# 261   1344765  SUSAN|A - A (MYSELF) SUSAN WEBB|55113    C00000935
# 264   1344765  SUSAN|A - A (MYSELF) SUSAN WEBB|55113    C00000935
#
#     actblue_committee_name
# 256                   DCCC
# 257                   DCCC
# 260                   DCCC
# 261                   DCCC
# 264                   DCCC

# %%
len(all_actblue)
# Out:
# 11470132

# %% [markdown]
# Note: Some committee IDs are either missing or cut off.

# %%
(
    all_actblue
    .loc[lambda df: df["actblue_committee_name"].isnull()]
    ["memo_text_description"]
    .value_counts()
)
# Out:
# Earmarked for CHC BOLD PAC/COMMITTEE FOR HISPANIC CAUSES BUILDING OUR LEADERSHIP DIVERSITY (C0036553    105743
# Earmarked for SARA GIDEON FOR MAINE ()                                                                   18141
# Earmarked for MJ FOR TEXAS ()                                                                            14450
# Earmarked for Democratic Nominee for -. Held pursuant to AOs 1977-16 and 1982-23                         13378
# Earmarked for SINEMA FOR ARIZONA ()                                                                      11769
# Earmarked for Democratic Nominee for KY-. Held pursuant to AOs 1977-16 and 1982-23                       11069
Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for ACTBLUE TECHNICAL SERVICES (27-0160261)                                                        1
# Earmarked for Democratic Nominee for AR-01. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for OH-10. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for AR-03. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for OH-15. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for NY PROGRESSIVE ACTION PAC2 ()                                                                  1
# Earmarked for INDIAN AMERICAN IMPACT FUND ()                                                                 1
# Earmarked for Democratic Nominee for AL-05. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for CA-04. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for WV-01. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for MLG PAC ()                                                                                     1
# Earmarked for Democratic Nominee for AR-04. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for WI-05. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for FL-. Held pursuant to AOs 1977-16 and 1982-23                           1
# Earmarked for Democratic Nominee for AZ-05. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for NE-01. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for CO-04. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for AZ-08. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for GA-12. Held pursuant to AOs 1977-16 and 1982-23                         1
# Earmarked for Democratic Nominee for UT-02. Held pursuant to AOs 1977-16 and 1982-23                         1
# Name: memo_text_description, dtype: int64

# %% [markdown]
# Note: In some cases, the same `committee_id` is associated with more than one committee name in the earmarks.

# %%
(
    all_actblue
    .groupby(["committee_id"])
    ["actblue_committee_name"]
    .nunique()
    .max()
)
# Out:
# 4

# %%
(
    all_actblue
    .loc[lambda df: df["committee_id"].isin(
        all_actblue
        .groupby(["committee_id"])
        ["actblue_committee_name"]
        .nunique()
        .loc[lambda x: x > 1]
        .index
    )]
    [[
        "committee_id",
        "actblue_committee_name"
    ]]
    .drop_duplicates()
    .sort_values([ "committee_id", "actblue_committee_name" ])
)
# Out:
#          committee_id  \
# 256         C00000935
# 1727802     C00000935
# 6014        C00005561
# 327836      C00005561
# 6279        C00010033
# 45295       C00010033
# 8615742     C00010603
# 312         C00010603
# 252279      C00010603
# 30515       C00019331
# 5505        C00019331
# 180495      C00024679
# 2820334     C00024679
# 7569        C00031054
# 3435043     C00031054
# 310532      C00071365
# 1184        C00071365
# 840911      C00135558
# 44989       C00135558
# 3478705     C00155952
# 5429        C00155952
# 16477       C00161786
# 4803314     C00161786
# 583203      C00165688
# 128459      C00165688
# 496         C00165688
# 75568       C00165688
# 3901944     C00166710
# 2372        C00166710
# 2376        C00166710
# 757         C00418897
# 6317250     C00418897
# 21536       C00460972
# 116653      C00460972
# 9398726     C00481978
# 9487        C00481978
# 2259        C00540443
# 279         C00540443
# 71196       C00620427
# 1516625     C00620427
# 2230        C00632133
# 34630       C00632133
# 1545        C00632133
# 1884        C00632554
# 1664        C00632554
# 363         C00633248
# 1502028     C00633248
# 73917       C00635664
# 5673800     C00635664
# 10938288    C00636027
# 222098      C00636027
# 288         C00638320
# 3441181     C00638320
# 167219      C00641555
# 8102204     C00641555
# 2681454     C00647784
# 5247200     C00647784
# 17762       C00654053
# 57950       C00654053
# 42502       C00670216
# 11764179    C00670216
# 20625       C00671040
# 211282      C00671040
# 129785      C00674697
# 12111479    C00674697
# 549216      C00678839
# 3065        C00678839
# 541         C00692319
# 28739       C00692319
# 124106      C00697151
# 1030349     C00697151
#
#                                                           actblue_committee_name
# 256                                                                         DCCC
# 1727802                                                        DCCC RECOUNT FUND
# 6014                 DEMOCRATIC EXECUTIVE COMMITTEE OF FLORIDA - FEDERAL ACCOUNT
# 327836                           FLORIDA DEMOCRATIC PARTY RECOUNT FUND - FEDERAL
# 73917                                       WOMEN FOR AMERICAN VALUES AND ETHICS
# 5673800                          WOMEN FOR AMERICAN VALUES AND ETHICS - I.E. PAC
# 10938288                                                      TECH FOR CAMPAIGNS
# 222098                                            TECH FOR CAMPAIGNS - UNLIMITED
# 288                                                                         DAGA
# 3441181                                                         DAGA - UNLIMITED
# 167219                                                       SQUARE ONE POLITICS
# 8102204                                          SQUARE ONE POLITICS - UNLIMITED
# 2681454                                   THE PEOPLE - SUPER PAC (ADMIN ACCOUNT)
# 5247200                                                           THE PEOPLE PAC
# 17762                                                            FUTURE NOW FUND
# 57950                                           VIRGINIA DOOR-KNOCKING CHALLENGE
# 42502                                          YOUTH PROGRESSIVE ACTION CATALYST
# 11764179                            YOUTH PROGRESSIVE ACTION CATALYST - UNLIMTED
# 20625                                                             RURAL PROGRESS
# 211282                                                RURAL PROGRESS - UNLIMITED
# 129785                                                               SUNRISE PAC
# 12111479                                                 SUNRISE PAC - UNLIMITED
# 549216                                                        INDIVISIBLE ACTION
# 3065                               INDIVISIBLE ACTION (NON-CONTRIBUTION ACCOUNT)
# 541                                                     VOTER PROTECTION PROJECT
# 28739                                       VOTER PROTECTION PROJECT - UNLIMITED
# 124106                                                             ELECTAAPI.ORG
# 1030349                                                ELECTAAPI.ORG - UNLIMITED

# %%
assert (
    all_actblue
    .groupby(["actblue_committee_name"])
    ["committee_id"]
    .nunique()
    .max()
) == 1

# %% [markdown]
# Get the candidate names using commitee IDs

# %%
candidates = pd.read_csv("../data/candidates.csv").rename(
    columns = {
        "Committee ID": "committee_id",
        "Committee Name": "committee_name",
        "Candidate Name": "candidate_name"
    }
)

candidates.head(3)
# Out:
#   candidate_name                committee_name Candidate ID committee_id
# 0    Cory Booker                     Cory 2020    P00009795    C00695510
# 1  Kamala Harris  Kamala Harris for the People    P00009423    C00694455
# 2      Joe Biden           Biden for President    P80000722    C00703975

# %% [markdown]
# Merge with candidates to get names

# %%
(
    candidates
    .loc[lambda df: ~df["committee_id"].isin(all_actblue["committee_id"].unique())]
)
# Out:
#    candidate_name                 committee_name Candidate ID committee_id
# 23   Donald Trump  Donald J. Trump for President    P80001571    C00580100
# 25     Tom Steyer               Tom Steyer 2020     P00012716    C00711614

# %%
with_candidates = (
    candidates
    .loc[lambda df: df["committee_id"].isin(all_actblue["committee_id"].unique())]    
    .merge(
        all_actblue,
        on = "committee_id",
        how = "left",
        validate = "1:m"
    )
)

# Visually inspect to make sure committee names and candidate names match
(
    with_candidates
    [['committee_name', 'actblue_committee_name', 'committee_id']]
    .drop_duplicates()
)
# Out:
#                                           committee_name  \
# 0                                              Cory 2020
# 140043                      Kamala Harris for the People
# 644793                               Biden for President
# 1067513                                  Amy for America
# 1204475                                      Bernie 2020
# 3025194                             Warren for President
# 3837822                                 Pete for America
# 4462026                                 Beto for America
# 4780573                            Julián for the Future
# 4950853                          Friends of John Delaney
# 4959092                               Inslee for America
# 5072306                                  Gillibrand 2020
# 5169780                                Hickenlooper 2020
# 5187323                           Friends of Andrew Yang
# 5364643                                        Tulsi Now
# 5505181  Mike Gravel for President Exploratory Committee
# 5558800                           Tim Ryan Victory Fund
# 5572116                             Swalwell for America
# 5597269                         Wayne Messam for America
# 5598789                Marianne Williamson for President
# 5710347                            Bullock for President
# 5735217                         Seth Moulton for America
# 5752515                               Bennet for America
# 5789336                                   De Blasio 2020
#
#                                 actblue_committee_name committee_id
# 0                                            CORY 2020    C00695510
# 140043                    KAMALA HARRIS FOR THE PEOPLE    C00694455
# 644793                             BIDEN FOR PRESIDENT    C00703975
# 1067513                                AMY FOR AMERICA    C00696419
# 1204475                                    BERNIE 2020    C00696948
# 3025194                     WARREN FOR PRESIDENT, INC.    C00693234
# 3837822                          PETE FOR AMERICA, INC    C00697441
# 4462026                               BETO FOR AMERICA    C00699090
# 4780573                          JULIAN FOR THE FUTURE    C00693044
# 4950853                        FRIENDS OF JOHN DELANEY    C00508416
# 4959092                             INSLEE FOR AMERICA    C00698050
# 5072306                                GILLIBRAND 2020    C00694018
# 5169780                              HICKENLOOPER 2020    C00698258
# 5187323                         FRIENDS OF ANDREW YANG    C00659938
# 5364643                                      TULSI NOW    C00693713
# 5505181  COMMITTEE FOR PEACE, JUSTICE, AND MIKE GRAVEL    C00700609
# 5558800                           TIM RYAN FOR AMERICA    C00701979
# 5572116                           SWALWELL FOR AMERICA    C00701698
# 5597269                              WAYNE FOR AMERICA    C00699280
# 5598789              MARIANNE WILLIAMSON FOR PRESIDENT    C00696054
# 5710347                          BULLOCK FOR PRESIDENT    C00706416
# 5735217                  SETH MOULTON FOR AMERICA, INC    C00704510
# 5752515                             BENNET FOR AMERICA    C00705186
# 5789336                                 DE BLASIO 2020    C00706697

# %% [markdown]
# Get the aggregate amount a donor has given to a particular candidate

# %%
latest_contribs = (
    with_candidates
    .sort_values('contribution_date')
    .groupby(['donor_id','candidate_name'])
    .pipe(lambda grp: pd.DataFrame({
        "latest_contribution_aggregate": grp["contribution_aggregate"].last(),
        })
    )
    .reset_index()
)

latest_contribs.sort_values(
    'latest_contribution_aggregate',
    ascending = False
).head(3)
# Out:
#                         donor_id  candidate_name  \
# 1784359  LARRY|ROCKEFELLER|10020       Joe Biden
# 1625558   KATHARINE|RAYNER|10021  Pete Buttigieg
# 2184389      MICHAEL|LEWIS|90210       Joe Biden
#
#          latest_contribution_aggregate
# 1784359                        28000.0
# 1625558                        20800.0
# 2184389                        19600.0

# %% [markdown]
# Write out

# %%
latest_contribs.to_csv(
    "../output/latest_contribs.csv", 
    index = False
)

# %% [markdown]
# Merge with latest_contrib to get latest

# %%
clean_actblue = with_candidates.merge(
    latest_contribs,
    on = ["donor_id", 'candidate_name'],
    how = "left"
)

# %% [markdown]
# Write out

# %%
clean_actblue.to_csv(
    "../output/clean_actblue.csv", 
    index = False)

# %% [markdown]
# Time out

# %%
end = datetime.datetime.now()

d = (end - start)

f"The notebook ran for {round(d.total_seconds() / 60, 2) } minutes"
# Out:
# 'The notebook ran for 20.18 minutes'

# %% [markdown]
# ---
#
# ---
#
# ---
